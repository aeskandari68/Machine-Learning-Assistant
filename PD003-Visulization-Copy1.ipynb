# %% [markdown]
# Lets wanalyse the PD003

# %%
DF003.isnull().sum()
# Out:
# Date                   1
# Eating window (hrs)    7
# Weight Kg              5
# Cals ( kcal)           0
# Fat( g)                0
# Sat( g)                0
# Carbs( g)              0
# Fiber( g)              0
# Sugar( g)              0
# Prot( g)               0
# Sod( mg)               0
# Chol( mg)              2
# Potassium( mg)         1
# dtype: int64

# %% [markdown]
# # Assumption
# 1. missing values for features will be zero
# 2. Drop the first date, no data for weight

# %%
# Out:
# Date                   0
# Eating window (hrs)    6
# Weight Kg              4
# Cals ( kcal)           0
# Fat( g)                0
# Sat( g)                0
# Carbs( g)              0
# Fiber( g)              0
# Sugar( g)              0
# Prot( g)               0
# Sod( mg)               0
# Chol( mg)              0
# Potassium( mg)         0
# dtype: int64

# %%
# Out:
#                      count         mean          std     min        25%  \
# Eating window (hrs)   41.0     9.648537     1.901742    1.00     9.0000
# Weight Kg             43.0    78.852326     1.366824   76.20    77.7000
# Cals ( kcal)          47.0  1788.744681   524.136825  173.00  1603.0000
# Fat( g)               47.0    75.253830    28.274565   12.00    58.7850
# Sat( g)               47.0    25.532851    11.391352    6.00    17.1245
# Carbs( g)             47.0   202.184043    69.526311   12.30   165.5000
# Fiber( g)             47.0    22.878298     8.077691    0.90    17.4650
# Sugar( g)             47.0    56.801277    32.177979    4.27    34.9050
# Prot( g)              47.0    64.597872    25.110357    3.90    51.1300
# Sod( mg)              47.0  1973.389574  1353.586281   72.00  1125.3000
# Chol( mg)             47.0    48.303191    76.703373    0.00     0.0000
# Potassium( mg)        47.0  1099.310638   867.157147    0.00   587.0000
#
# ...

# %%
features = DF003.columns
features
# Out:
# Index(['Date', 'Eating window (hrs)', 'Weight Kg', 'Cals ( kcal)', 'Fat( g)',
#        'Sat( g)', 'Carbs( g)', 'Fiber( g)', 'Sugar( g)', 'Prot( g)',
#        'Sod( mg)', 'Chol( mg)', 'Potassium( mg)'],
#       dtype='object')

# %% [markdown]
# Check for outliers

# %% [markdown]
# Check the corrlolation

# %%
# Out:
# <style type="text/css">
# #T_8b4a0_row0_col0 {
#   background-color: #ff0000;
#   color: #f1f1f1;
# }
# #T_8b4a0_row1_col0 {
#   background-color: #f88383;
#   color: #f1f1f1;
# }
# #T_8b4a0_row2_col0 {
#   background-color: #f79a9a;
#   color: #000000;
# }
# #T_8b4a0_row3_col0 {
#   background-color: #f79f9f;
#   color: #000000;
# }
# #T_8b4a0_row4_col0 {
#   background-color: #f7a7a7;
#   color: #000000;
# }
# #T_8b4a0_row5_col0 {
#   background-color: #f6b0b0;
#   color: #000000;
# }
# #T_8b4a0_row6_col0 {
#   background-color: #f6baba;
#   color: #000000;
# }
# #T_8b4a0_row7_col0 {
#   background-color: #f5bebe;
#   color: #000000;
# }
# #T_8b4a0_row8_col0 {
#   background-color: #f4d1d1;
#   color: #000000;
# }
# #T_8b4a0_row9_col0 {
#   background-color: #f4dbdb;
#   color: #000000;
# }
# #T_8b4a0_row10_col0 {
#   background-color: #f4dcdc;
#   color: #000000;
# }
# #T_8b4a0_row11_col0 {
#   background-color: #f3f0f0;
#   color: #000000;
# }
# </style>
# <table id="T_8b4a0">
# ...
