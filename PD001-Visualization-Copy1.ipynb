# %% [markdown]
# Lets wanalyse the PD001

# %%
DF001.isnull().sum()
# Out:
# Date                    9
# Eating Window (Hrs)    19
# Daily Weight Data       9
# Cals ( kcal)           10
# Fat( g)                10
# Sat( g)                10
# Carbs( g)              10
# Fiber( g)              10
# Sugar( g)              10
# Prot( g)               10
# Sod( mg)               10
# Chol( mg)              10
# Potassium( mg)         10
# Body fat % Scales      33
# dtype: int64

# %% [markdown]
# Because we do not have any data on PD001 food features for February, and we do not have weight data after 10th of April, we are not considering these periods.

# %%
# Out:
#                      count         mean          std      min       25%  \
# Eating Window (Hrs)   41.0     9.481707     1.643539    6.000     8.500
# Daily Weight Data     41.0    62.717073     0.775533   61.400    62.200
# Cals ( kcal)          41.0  1605.682927   446.282166  961.000  1317.000
# Fat( g)               41.0    67.976585    27.283481   29.230    49.260
# Sat( g)               41.0    22.644439     9.934887    6.386    15.861
# Carbs( g)             41.0   134.963415    51.711553   45.920    93.340
# Fiber( g)             41.0    20.053415    10.553406    4.700    13.100
# Sugar( g)             41.0    41.736829    22.491404   12.780    29.510
# Prot( g)              41.0    68.169756    18.776319   34.050    57.420
# Sod( mg)              41.0  1908.028780  1177.673455  511.270  1188.110
# Chol( mg)             41.0   345.817073   186.672968    6.000   241.000
# Potassium( mg)        41.0  1593.756098   686.450027  552.000  1085.000
# ...

# %%
features = DF001.columns

# %%
DF001.hist(figsize= (50,40))
plt.show()

# %% [markdown]
# Check for outliers

# %%
# Out:
# <AxesSubplot:ylabel='Body fat % Scales'>

# %% [markdown]
# Check the corrlolation

# %%
# Out:
# <style type="text/css">
# #T_bf733_row0_col0 {
#   background-color: #ff0000;
#   color: #f1f1f1;
# }
# #T_bf733_row1_col0 {
#   background-color: #fd2a2a;
#   color: #f1f1f1;
# }
# #T_bf733_row2_col0 {
#   background-color: #fa6666;
#   color: #f1f1f1;
# }
# #T_bf733_row3_col0 {
#   background-color: #f6a8a8;
#   color: #000000;
# }
# #T_bf733_row4_col0 {
#   background-color: #f6b6b6;
#   color: #000000;
# }
# #T_bf733_row5_col0 {
#   background-color: #f6b7b7;
#   color: #000000;
# }
# #T_bf733_row6_col0 {
#   background-color: #f6b8b7;
#   color: #000000;
# }
# #T_bf733_row7_col0 {
#   background-color: #f6baba;
#   color: #000000;
# }
# #T_bf733_row8_col0 {
#   background-color: #f4d4d4;
#   color: #000000;
# }
# #T_bf733_row9_col0 {
#   background-color: #f4d8d8;
#   color: #000000;
# }
# #T_bf733_row10_col0 {
#   background-color: #f4dfdf;
#   color: #000000;
# }
# #T_bf733_row11_col0 {
#   background-color: #f3e7e7;
#   color: #000000;
# }
# #T_bf733_row12_col0 {
# ...
